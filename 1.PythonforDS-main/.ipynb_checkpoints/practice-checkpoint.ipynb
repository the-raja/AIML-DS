# %%
name = ["Satyajit" , "Neha", 0 , 0.0, "", "Namrata"]

# %%
filter(None, name)

# %%
list(filter(None, name))
# Out:
# ['Satyajit', 'Neha', 'Namrata']

# %%
number = [12 , 18 , 51 , 5 , 9 , 0 , 9 , 0.0 , ""]

# %%
filter(None, number)

# %%
list(filter(None, number))
# Out:
# [12, 18, 51, 5, 9, 9]

# %%
from functools import reduce

# %%
data = [1,2,3,4,5]

# %%
mul = lambda x,y : x*y

# %%
reduce(mul, data)
# Out:
# 120

# %%
file = open('test.txt' , 'w')
file.write("This is a write Operation")
file.write(" Hello! I am Raja Kumar")
file.write(" I am Curently learning ALMS & DS")
file.close()

# %%
file = open('test.txt', 'r')
print(file.read())
# Out:
# This is a write Operation Hello! I am Raja KumarI am Curently learning ALMS & DS

# %% [markdown]
# ###Append Operation

# %%
with open('test.txt' , 'a') as file:
    file.write("This is Appended Later")

# %%
file = open('test.txt' , 'r')
for line in file:
    print(line)
# Out:
# This is a write Operation Hello! I am Raja KumarI am Curently learning ALMS & DSThis is Appended Later
